# %% [markdown]
# # Final model setup

# %%
import os
import logging
from ultralytics import YOLO
from pathlib import Path
from helpers import save_yolo_labels, convert_xywhn_to_x1y1x2y2, show_labeled_image, load_image, print_tree
import matplotlib.pyplot as plt

# %%
logging.basicConfig(level=logging.INFO,filename='detection.log', filemode='w', format='%(asctime)s - %(message)s', datefmt='%d-%b-%y %H:%M:%S')

# %%
DATASETS_ROOT_PATH = r"D:\master_thesis_wd\datasets"
DETECTION_AND_CLASSIFICATION_DATASET_PATH = os.path.join(DATASETS_ROOT_PATH, "detection_and_classification_dataset")

# %%
model = YOLO("yolov8n.yaml")
model_train = model.train(data="detection_and_classification_config.yaml", 
                          epochs=100,
                          imgsz=640,
                          dropout=0.2,
                          batch=32,
                          degrees=0.25, 
                          scale=0.3,
                          perspective=0.0001,
                        )
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3157200 parameters, 3157184 gradients, 8.9 GFLOPs
#
# New https://pypi.org/project/ultralytics/8.1.5 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.1 🚀 Python-3.10.6 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# engine\trainer: task=detect, mode=train, model=yolov8n.yaml, data=detection_and_classification_config.yaml, epochs=100, time=None, patience=50, batch=32, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train9, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.2, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.25, translate=0.1, scale=0.3, shear=0.0, perspective=0.0001, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=C:\Users\Jakub Lechowski\Desktop\master-thesis\code\runs\detect\train9
# Overriding model.yaml nc=80 with nc=9
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    753067  ultralytics.nn.modules.head.Detect           [9, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3012603 parameters, 3012587 gradients, 8.2 GFLOPs
#
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning D:\master_thesis_wd\datasets\detection_and_classification_dataset\train\labels.cache... 1056 images, 0
# val: Scanning D:\master_thesis_wd\datasets\detection_and_classification_dataset\val\labels.cache... 264 images, 0 backg
# Plotting labels to C:\Users\Jakub Lechowski\Desktop\master-thesis\code\runs\detect\train9\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000769, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      4.29G      2.957      4.967      4.263         56        640: 100%|██████████| 33/33 [00:09<00:00,  3.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266   0.000222      0.056   0.000139   2.85e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100       4.3G      2.766      4.213      3.654         63        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266   0.000297     0.0218   0.000159   3.99e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100       4.3G      2.327      3.562      3.043         50        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266   0.000297     0.0218   0.000159   3.99e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100       4.3G      1.924      3.071      2.584         59        640: 100%|██████████| 33/33 [00:07<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266    0.00662      0.463     0.0572     0.0189
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100       4.3G      1.679      2.783      2.291         60        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.502      0.296      0.201     0.0966
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100       4.3G      1.592      2.578      2.167         59        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.666      0.541      0.481       0.25
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100       4.3G      1.485      2.435      2.051         65        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266       0.27      0.652      0.452      0.305
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100       4.3G      1.461      2.334      2.009         67        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.431      0.698      0.514      0.365
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100       4.3G      1.404      2.195      1.917         60        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.289      0.674      0.453      0.317
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100       4.3G      1.367      2.113      1.877         56        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.356      0.596      0.447      0.331
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.29G      1.316      1.971      1.837         54        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.285      0.567        0.4      0.289
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.43G       1.32      1.917      1.841         69        640: 100%|██████████| 33/33 [00:07<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.573      0.686       0.61      0.445
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      4.43G      1.307      1.819      1.817         62        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.541      0.682      0.693      0.499
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100       4.3G      1.303        1.8        1.8         63        640: 100%|██████████| 33/33 [00:07<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266       0.55      0.707      0.666      0.468
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.29G      1.274      1.732      1.785         54        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.342      0.688      0.491      0.364
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100       4.3G      1.241      1.711      1.761         69        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.772      0.626      0.755      0.558
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.29G      1.237      1.608      1.745         59        640: 100%|██████████| 33/33 [00:07<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.494      0.665       0.61      0.421
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100       4.3G       1.19      1.623      1.722         60        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.503       0.81      0.691      0.517
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      4.43G      1.247      1.606      1.721         62        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.707      0.638      0.669      0.506
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100       4.3G      1.197      1.561      1.708         64        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.757      0.688      0.758       0.56
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      4.29G      1.184      1.475      1.675         72        640: 100%|██████████| 33/33 [00:06<00:00,  4.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.529      0.781      0.696      0.519
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100
cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8n summary (fused): 168 layers, 3007403 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:01<0
#                    all        264        266      0.929      0.917      0.966        0.8
#              Basophile        264         35       0.99          1      0.995      0.833
#            Eosinophile        264         27      0.965      0.926       0.98      0.756
#            Lymphoblast        264         45      0.979          1      0.995      0.836
#             Lymphocyte        264         23          1      0.972      0.995      0.895
#               Monocyte        264         32          1      0.968      0.991        0.8
#             Myeloblast        264         41      0.929      0.962      0.985      0.794
#       Neutrophile Band        264          7       0.69      0.429       0.81      0.668
#    Neutrophile Segment        264         25      0.861      0.994      0.947      0.775
#             Normoblast        264         31      0.951          1      0.995      0.845
# Speed: 0.5ms preprocess, 1.8ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to C:\Users\Jakub Lechowski\Desktop\master-thesis\code\runs\detect\train9

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.1.1 🚀 Python-3.10.6 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8n summary (fused): 168 layers, 3007403 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\master_thesis_wd\datasets\detection_and_classification_dataset\val\labels.cache... 264 images, 0 backg
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 9/9 [00:04<0
#                    all        264        266       0.93      0.917      0.966      0.801
#              Basophile        264         35       0.99          1      0.995      0.837
#            Eosinophile        264         27      0.964      0.926       0.98      0.756
#            Lymphoblast        264         45       0.98          1      0.995      0.836
#             Lymphocyte        264         23          1      0.971      0.995      0.895
#               Monocyte        264         32          1      0.969      0.991        0.8
#             Myeloblast        264         41      0.929      0.963      0.985      0.794
#       Neutrophile Band        264          7      0.692      0.429       0.81      0.668
#    Neutrophile Segment        264         25      0.861      0.992      0.947      0.778
#             Normoblast        264         31      0.952          1      0.995      0.843
# Speed: 0.4ms preprocess, 3.5ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to C:\Users\Jakub Lechowski\Desktop\master-thesis\code\runs\detect\train92

# %%
# %matplotlib inline

import seaborn as sns
sns.heatmap(metrics.confusion_matrix.matrix,
            annot=True,
            cmap="Blues",
            xticklabels=["Basophile",
                         "Eosinophile",
                         "Lymphoblast",
                         "Lymphocyte",
                         "Monocyte",
                         'Myeloblast',
                         "Neutrophile Band",
                         "Neutrophile Segment",
                         "Normoblast",
                         "background"],
            yticklabels=["Basophile",
                         "Eosinophile",
                         "Lymphoblast",
                         "Lymphocyte",
                         "Monocyte",
                         'Myeloblast',
                         "Neutrophile Band",
                         "Neutrophile Segment",
                         "Normoblast",
                         "background",])
plt.ylabel('Predicted')
plt.xlabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
metrics.results_dict
# Out:
# {'metrics/precision(B)': 0.9297539363566008,
#  'metrics/recall(B)': 0.9165523568774954,
#  'metrics/mAP50(B)': 0.9660315757307784,
#  'metrics/mAP50-95(B)': 0.8006162206419977,
#  'fitness': 0.8171577561508757}

# %%
import pandas as pd
def predict_labels(yolo_model, img_dir: str, label_dir: str):
    predictions = yolo_model.predict(img_dir, save=False, verbose=True, stream=True)
        
    item_df = pd.DataFrame(
        columns=[
            "img_name",
            "label",
            "x_center",
            "y_center",
            "width",
            "height",
        ]
    )
    for item in predictions:
        image_name = os.path.splitext(os.path.basename(item.path))[0]
        n_objects_detected = item.boxes.shape[0]

        for i in range(n_objects_detected):
            row = {}
            row["img_name"] = image_name
            row["label"] = int(item.boxes.cls[i].tolist())
            row["x_center"] =  item.boxes.xywhn[i][0].tolist()
            row["y_center"] =  item.boxes.xywhn[i][1].tolist()
            row["width"] =  item.boxes.xywhn[i][2].tolist()
            row["height"] =  item.boxes.xywhn[i][3].tolist()
            row_df = pd.DataFrame(row, index=[0])
            item_df = pd.concat([item_df, row_df])
    save_yolo_labels(item_df, label_dir)
    return item_df

# %%
DATASET_4_PATH = r"D:\master_thesis_wd\datasets\dataset4"

# %%
if not os.path.exists(os.path.join(DATASET_4_PATH, "predicted_yolo_labels")):    
    os.mkdir(os.path.join(DATASET_4_PATH, "predicted_yolo_labels"))

# %%
labels = predict_labels(model, os.path.join(DATASET_4_PATH, "images"),  os.path.join(DATASET_4_PATH, "predicted_yolo_labels"))
# Out:
# image 1/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1445.tif: 512x640 (no detections), 89.4ms
# image 2/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1486.tif: 544x640 (no detections), 77.1ms
# image 3/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1487.tif: 544x640 (no detections), 4.0ms
# image 4/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1488.tif: 544x640 1 Neutrophile Segment, 4.0ms
# image 5/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1489.tif: 544x640 (no detections), 3.5ms
# image 6/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1490.tif: 544x640 (no detections), 4.0ms
# image 7/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1491.tif: 544x640 (no detections), 4.0ms
# image 8/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1492.tif: 544x640 (no detections), 4.6ms
# image 9/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1493.tif: 544x640 (no detections), 3.0ms
# image 10/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1494.tif: 544x640 (no detections), 3.0ms
# image 11/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1495.tif: 544x640 (no detections), 3.0ms
# image 12/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1496.tif: 544x640 (no detections), 3.0ms
# image 13/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1497.tif: 544x640 (no detections), 5.0ms
# image 14/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1498.tif: 544x640 (no detections), 3.0ms
# image 15/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1499.tif: 544x640 1 Neutrophile Segment, 4.0ms
# image 16/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1500.tif: 544x640 (no detections), 4.0ms
# image 17/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1501.tif: 544x640 1 Neutrophile Segment, 4.0ms
# image 18/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1502.tif: 544x640 (no detections), 3.0ms
# image 19/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1503.tif: 544x640 (no detections), 4.0ms
# image 20/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1504.tif: 544x640 (no detections), 4.0ms
# image 21/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1505.tif: 544x640 (no detections), 5.0ms
# image 22/23 D:\master_thesis_wd\datasets\dataset4\images\Snap-1506.tif: 544x640 (no detections), 5.0ms
# image 23/23 D:\master_thesis_wd\datasets\dataset4\images\snap.tif: 640x608 (no detections), 81.0ms
# Speed: 2.7ms preprocess, 14.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 608)
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 299.98it/s]

# %%
import random

# %%
invert_wbc_dataset4_labels= {
    "0": 'Basophile',
    "1": 'Eosinophile',
    "2": 'Lymphoblast',
    "3": 'Lymphocyte',
    "4": 'Monocyte',
    "5": 'Myeloblast',
    "6": "Neutrophile Band",
    "7": "Neutrophile Segment",
    "8": "Normoblast",
}

# %%
IMAGES_PATH = os.path.join(DATASET_4_PATH, "images")
YOLO_LABELS_PATH =  os.path.join(DATASET_4_PATH, "predicted_yolo_labels")
for image_path in random.sample(os.listdir(IMAGES_PATH), 23):
    label_path = os.path.join(YOLO_LABELS_PATH, os.path.splitext(image_path)[0] + ".txt")
    if not os.path.exists(label_path):
        continue
    show_labeled_image(os.path.join(IMAGES_PATH, image_path), label_path, label_map = invert_wbc_dataset4_labels)
